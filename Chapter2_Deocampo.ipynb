# %% [markdown]
# ## **Exercise 1**

# %%
name = input('Enter your name: ')
print('Hello ',name)
# Out:
# Enter your name: AJ
# Hello  AJ

# %% [markdown]
# ### **Exercise 2**

# %%
hours = input('Enter hours: ')
rate = input('Enter rate: ')
pay = float(hours) * float(rate)
print('Pay: ',pay)
# Out:
# Enter hours: 35
# Enter rate: 2.75
# Pay:  96.25

# %% [markdown]
# ### **Exercise 3**

# %%
width = 17
height = 12.0

print(width //2, type(width //2))
print(width /2.0, type(width /2.0))
print(height /3, type(height /3))
print(1+2*5,type(1+2*5))
# Out:
# 8 <class 'int'>
# 8.5 <class 'float'>
# 4.0 <class 'float'>
# 11 <class 'int'>

# %% [markdown]
# ### **Exercise 4**

# %%
num = input('Enter a number: ')
print('The square of', num,'is',int(num)**2)
# Out:
# Enter a number: 3
# The square of 3 is 9

# %% [markdown]
# ### **Challenge**

# %%
celsius = float(input('Enter temperature in Celsius: '))
fahrenheit = (celsius * 9/5) + 32
print('Temperature in fahrenheit in Celsius:',fahrenheit)
# Out:
# Enter temperature in Celsius: 16
# Temperature in fahrenheit in Celsius: 60.8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/IS110_BPerformance_Deocampo
# Out:
# /content/drive/MyDrive/IS110_BPerformance_Deocampo

# %%
# !git clone https://janadriandeocampo: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@github.com/janadriandeocampo/IS110_repo_Deocampo.git
# Out:
# Cloning into 'IS110_repo_Deocampo'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd /content/drive/MyDrive/IS110_BPerformance_Deocampo/IS110_repo_Deocampo
# Out:
# /content/drive/MyDrive/IS110_BPerformance_Deocampo/IS110_repo_Deocampo

# %%
# !pwd
# Out:
# /content/drive/MyDrive/IS110_BPerformance_Deocampo/IS110_repo_Deocampo

# %%
# !cp /content/drive/MyDrive/IS110_BPerformance_Deocampo/Chapter2_Deocampo.ipynb /content/drive/MyDrive/IS110_BPerformance_Deocampo/IS110_repo_Deocampo

# %%
# !cp -r /content/drive/MyDrive/IS110_BPerformance_Deocampo/PythonEnvi_deocampo /content/drive/MyDrive/IS110_BPerformance_Deocampo/IS110_repo_Deocampo

# %%
# !cp /content/drive/MyDrive/IS110_BPerformance_Deocampo/01_Python_Fundamentals_Part1_Workbook.ipynb /content/drive/MyDrive/IS110_BPerformance_Deocampo/IS110_repo_Deocampo

# %%
ls
# Out:
# NewUpload.txt

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/IS110_BPerformance_Deocampo/IS110_repo_Deocampo/.git/

# %%
# !git add

# %%
# !git reset --hard
# Out:
# Updating files: 100% (489/489), done.
# HEAD is now at 1d39eab new commit

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git commit -m "new commit"
# Out:
# [main c38a814] new commit
#  488 files changed, 131850 insertions(+)
#  create mode 100644 01_Python_Fundamentals_Part1_Workbook.ipynb
#  create mode 100644 Chapter2_Deocampo.ipynb
#  create mode 100644 PythonEnvi_deocampo/env_Deocampo/bin/activate
#  create mode 100644 PythonEnvi_deocampo/env_Deocampo/bin/activate.csh
#  create mode 100644 PythonEnvi_deocampo/env_Deocampo/bin/activate.fish
#  create mode 100644 PythonEnvi_deocampo/env_Deocampo/bin/activate.nu
#  create mode 100644 PythonEnvi_deocampo/env_Deocampo/bin/activate.ps1
#  create mode 100644 PythonEnvi_deocampo/env_Deocampo/bin/activate_this.py
#  create mode 100644 PythonEnvi_deocampo/env_Deocampo/bin/pip
#  create mode 100644 PythonEnvi_deocampo/env_Deocampo/bin/pip-3.12
#  create mode 100644 PythonEnvi_deocampo/env_Deocampo/bin/pip3
#  create mode 100644 PythonEnvi_deocampo/env_Deocampo/bin/pip3.12
#  create mode 100644 PythonEnvi_deocampo/env_Deocampo/lib/python3.12/site-packages/pip-26.0.1.dist-info/INSTALLER
# ...

# %%
# !git config --global user.email "janadrian.deocampo@students.isatu.edu.ph"
# !git config --global user.name "janadriandeocampo"

# %%
# !git reset --soft HEAD~1
